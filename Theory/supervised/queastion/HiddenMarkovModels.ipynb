# %% [markdown]
# What is a Hidden Markov Model (HMM)?
#
# What are the key components of an HMM?
#
# What makes HMM "hidden"?
#
# What are the three fundamental problems of HMM?
#
# What's the difference between Markov Model and Hidden Markov Model?
#
# What are real-world applications of HMM?
#
# What assumptions does HMM make?
#
# HMM Parameters
# What are the λ = (A, B, π) parameters in HMM?
#
# What is the transition probability matrix A?
#
# What is the emission probability matrix B?
#
# What is the initial state distribution π?
#
# How many parameters does an HMM with N states and M observations have?
#
# What does "observation independence assumption" mean in HMM?
#
# Forward Algorithm
# What problem does the Forward Algorithm solve?
#
# Write the recursion formula for Forward Algorithm
#
# What is the time complexity of Forward Algorithm?
#
# Why do we need scaling in Forward Algorithm?
#
# How does Forward Algorithm handle underflow?
#
# What is α-pass in Forward Algorithm?
#
# How is Forward Algorithm used to compute P(O|λ)?
#
# Backward Algorithm
# What problem does the Backward Algorithm solve?
#
# Write the recursion formula for Backward Algorithm
#
# What is the relationship between Forward and Backward probabilities?
#
# Why do we need both Forward and Backward algorithms?
#
# How are they used together in Baum-Welch algorithm?
#
# Forward-Backward Algorithm
# What is the Forward-Backward algorithm?
#
# What does ξ_t(i,j) represent?
#
# What does γ_t(i) represent?
#
# How are ξ and γ calculated from α and β?
#
# What is the smoothing problem in HMM?
#
#
# What problem does Viterbi Algorithm solve?
#
# What is the difference between Viterbi and Forward Algorithm?
#
# Write the Viterbi recursion formula
#
# What is the time complexity of Viterbi Algorithm?
#
# How do you perform backtracking in Viterbi?
#
# What is δ_t(i) in Viterbi Algorithm?
#
# What is ψ_t(i) in Viterbi Algorithm?
#
# Why is Viterbi called "max-sum" while Forward is "sum-sum"?
#
# How does Viterbi find the most likely state sequence?
#
# What are practical applications of Viterbi decoding?
#
# What problem does Baum-Welch Algorithm solve?
#
# Why is Baum-Welch an Expectation-Maximization algorithm?
#
# What are the E-step and M-step in Baum-Welch?
#
# Write the re-estimation formulas for A, B, π
#
# Why does Baum-Welch only find local maxima?
#
# How do you initialize Baum-Welch algorithm?
#
# What are convergence criteria for Baum-Welch?
#
# How to handle multiple observation sequences in Baum-Welch?
#
#
# Prove the Markov property for HMM
#
# Derive the Forward Algorithm recursion
#
# Derive the Backward Algorithm recursion
#
# Prove that Viterbi Algorithm finds the optimal state sequence
#
# Derive the re-estimation formulas for Baum-Welch
#
# What is the likelihood function for HMM?
#
# How to compute P(O|λ) using Forward Algorithm?
#
#
# How to handle numerical underflow in HMM algorithms?
#
# What scaling techniques are used in Forward-Backward?
#
# How to implement log-space versions of algorithms?
#
# What data structures are efficient for HMM implementation?
#
# How to parallelize HMM algorithms?
#
# What is time complexity of Forward Algorithm for sequence length T?
#
# What is space complexity of Viterbi Algorithm?
#
# How does number of states N affect complexity?
#
# Compare complexities of Forward vs Viterbi
#
# What is the complexity of Baum-Welch per iteration?
#
#
# How is HMM used in speech recognition?
#
# How is HMM used in bioinformatics (gene finding)?
#
# How is HMM used in natural language processing?
#
# How is HMM used in finance (time series)?
#
# How is HMM used in activity recognition?
#
#
# What is a Continuous HMM (CHMM)?
#
# What is a Gaussian Mixture HMM (GMM-HMM)?
#
# What is a Factorial HMM?
#
# What is a Hierarchical HMM?
#
# What is a Hidden Semi-Markov Model (HSMM)?
#
# What is a Partially Observable Markov Decision Process (POMDP)?
#
#
# HMM vs Markov Model: When to use each?
#
# HMM vs Recurrent Neural Network (RNN)
#
# HMM vs Conditional Random Field (CRF)
#
# HMM vs Dynamic Bayesian Network
#
# HMM vs Kalman Filter
#
#
# How to choose number of hidden states?
#
# How to handle unknown words/observations in HMM?
#
# What regularization techniques exist for HMM?
#
# How to validate HMM model performance?
#
# What are common pitfalls in HMM training?
#
#
# What is the N-best Viterbi algorithm?
#
# What is the Forward-Backward-Testing algorithm?
#
# How does Beam Search relate to Viterbi?
#
# What is the Segment K-means algorithm?
#
# How to compute probability of being in state i at time t?
#
# How to compute probability of transition from i to j at time t?
#
# How to compute expected number of transitions from i to j?
#
# How to compute expected number of times in state i?
#
# How to compute probability of observation sequence?
#
#
# How to initialize HMM parameters?
#
# What is K-means initialization for HMM?
#
# What are problems with random initialization?
#
# How to use domain knowledge for initialization?
#
# What is uniform initialization and when to use it?
#
#
# Why does numerical underflow occur in HMM?
#
# What is log-likelihood scaling?
#
# How does scaling factor c_t work?
#
# How to recover actual probabilities after scaling?
#
# What are alternatives to scaling?
#
#
# How to train HMM with multiple observation sequences?
#
# How to handle sequences of different lengths?
#
# What is the modified Baum-Welch for multiple sequences?
#
# How to weight different sequences?
#
#
# What is perplexity in HMM?
#
# How to compute cross-validation for HMM?
#
# What is Bayesian Information Criterion (BIC) for HMM?
#
# How to test if HMM is overfitting?
#
# What metrics to use for sequence prediction?
#
#
# What is Laplace smoothing for emission probabilities?
#
# What is additive smoothing for transition probabilities?
#
# How does smoothing affect model performance?
#
# What is the optimal smoothing factor?
#
#
# Implement Forward Algorithm from scratch
#
# Implement Viterbi Algorithm from scratch
#
# Implement Baum-Welch Algorithm
#
# Write code to generate sequences from HMM
#
# Implement scaling in Forward-Backward
#
#
# Prove that Baum-Welch increases likelihood monotonically
#
# Show that Viterbi path has highest probability
#
# Prove that Forward Algorithm correctly computes P(O|λ)
#
# What is the relationship between EM and Baum-Welch?
#
# How is HMM related to mixture models?
#
#
# How to implement Viterbi with O(N) memory?
#
# What is checkpointing in Forward-Backward?
#
# How to handle very long sequences?
#
# What streaming algorithms exist for HMM?
#
#
# How to parallelize Forward Algorithm?
#
# How to parallelize Viterbi Algorithm?
#
# How to distribute Baum-Welch training?
#
# What are MapReduce implementations for HMM?
#
#
# What are left-to-right HMMs?
#
# What are Bakis models?
#
# How to enforce duration constraints in HMM?
#
# What are topology constraints in HMM?
#
#
# How to model continuous observations in HMM?
#
# What are Gaussian HMMs?
#
# What are GMM-HMMs?
#
# How to train continuous HMMs?
#
# What are emission distributions besides Gaussian?
#
#
# What is posterior decoding (Max-Marginal)?
#
# How does posterior decoding differ from Viterbi?
#
# What is N-best decoding?
#
# What is lattice decoding?
#
# What is confidence scoring in decoding?
#
# What is label bias problem in HMM?
#
# How to handle incomplete training data?
#
# What is online learning for HMM?
#
# How to update HMM with new data?
#
# What are incremental Baum-Welch algorithms?
#
#
# How to choose number of states?
#
# How to compare different HMM topologies?
#
# What is model merging/splitting for HMM?
#
# How to use BIC/AIC for HMM selection?
#
# What is cross-validation for HMM?
#
#
# How to handle unknown observations at test time?
#
# What to do when transition never observed in training?
#
# How to balance model complexity with data sparsity?
#
# How to incorporate prior knowledge into HMM?
#
# How to make HMM robust to noise?
#
#
# What is phone HMM in speech recognition?
#
# What is triphone HMM?
#
# How are HMMs used with MFCC features?
#
# What is Viterbi alignment in speech?
#
# How does HMM-GMM work in ASR?
#
#
# How is HMM used for gene finding?
#
# What is profile HMM for sequence alignment?
#
# How are HMMs used in protein structure prediction?
#
# What is Pair HMM?
#
# How to model CpG islands with HMM?
#
#
# How is HMM used for part-of-speech tagging?
#
# What is HMM for named entity recognition?
#
# How are HMMs used in machine translation?
#
# What is HMM for text segmentation?
#
# How to use HMM for topic modeling?
#
#
# How to use HMM for stock price prediction?
#
# What is HMM for regime detection?
#
# How to model economic cycles with HMM?
#
# What is HMM for anomaly detection?
#
# How to forecast with HMM?
#
#
# What is particle filtering for HMM?
#
# What is Gibbs sampling for HMM?
#
# How to do Bayesian inference for HMM?
#
# What is variational inference for HMM?
#
# How does belief propagation relate to HMM?
#
#
# What is gradient descent for HMM?
#
# What is conjugate gradient for HMM?
#
# How to use L-BFGS for HMM?
#
# What are second-order methods for HMM?
#
# How to handle constrained optimization in HMM?
#
#
# What are popular HMM libraries?
#
# How to use hmmlearn in Python?
#
# What are features of HTK (Hidden Markov Model Toolkit)?
#
# How to implement HMM in TensorFlow/PyTorch?
#
# What are Java libraries for HMM?
#
#
# "Design an HMM for POS tagging"
#
# "How would you detect fraudulent transactions with HMM?"
#
# "Implement Viterbi on whiteboard"
#
# "Explain Forward-Backward to a 10-year-old"
#
# "When would you NOT use HMM?"
#
#
# Prove Forward Algorithm correctness by induction
#
# Prove Viterbi optimality using dynamic programming principle
#
# Derive EM update rules for HMM
#
# Show relationship between α, β, γ, ξ
#
# Prove monotonic likelihood increase in Baum-Welch
