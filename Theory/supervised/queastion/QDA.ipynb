# %% [markdown]
# What is Linear Discriminant Analysis (LDA)?
#
# What is Quadratic Discriminant Analysis (QDA)?
#
# How do LDA/QDA differ from logistic regression?
#
# What are the main assumptions of LDA?
#
# What are the main assumptions of QDA?
#
# What problem does LDA solve? (Find linear combination that best separates classes)
#
# What is Fisher's Linear Discriminant?
#
#
# Derive the discriminant function for LDA
#
# Show that LDA assumes equal covariance matrices across classes
#
# Derive the decision boundary for LDA
#
# Show that LDA results in linear decision boundaries
#
# Derive the discriminant function for QDA
#
# Why does QDA result in quadratic decision boundaries?
#
# Write the Bayes classifier formula LDA/QDA is based on
#
#
# What does "Gaussian assumptions" mean in LDA/QDA?
#
# What happens if the Gaussian assumption is violated?
#
# How robust is LDA to violations of normality?
#
# What distributions can LDA handle besides Gaussian?
#
# How do you check if your data follows Gaussian distribution?
#
# What transformations can make data more Gaussian?
#
#
# What is the "equal covariance" assumption in LDA?
#
# How is the pooled covariance matrix calculated?
#
# Why does QDA use separate covariance matrices?
#
# How does the number of parameters differ between LDA and QDA?
#
# What happens when covariance matrices are singular?
#
#
# Prove that LDA gives linear decision boundaries
#
# Prove that QDA gives quadratic decision boundaries
#
# When would decision boundaries be parallel in LDA?
#
# Can LDA produce nonlinear boundaries? (No, unless using kernel trick)
#
# How many decision boundaries for K classes in LDA?
#
#
# LDA vs QDA: When to use each?
#
# LDA vs Logistic Regression: Similarities and differences
#
# LDA vs PCA: What's the fundamental difference?
#
# QDA vs Quadratic Logistic Regression
#
# LDA vs Naïve Bayes with Gaussian assumption
#
# Why choose LDA over more flexible methods?
#
#
# How is LDA related to Bayes' theorem?
#
# What are the prior probabilities in LDA?
#
# How do you estimate class priors?
#
# What is the connection between LDA and maximum likelihood?
#
#
# How is LDA used for dimensionality reduction?
#
# What's the difference between LDA for classification vs LDA for dimensionality reduction?
#
# How many dimensions can LDA reduce to? (max = K-1)
#
# Compare LDA with PCA for visualization
#
# Can QDA be used for dimensionality reduction?
#
#
# How do you handle categorical features in LDA/QDA?
#
# What preprocessing is required for LDA/QDA?
#
# How does LDA handle missing values?
#
# What are the computational requirements of LDA vs QDA?
#
# How to regularize LDA/QDA?
#
#
# What is Regularized Discriminant Analysis (RDA)?
#
# How does RDA interpolate between LDA and QDA?
#
# What's the regularization parameter in RDA?
#
# When would you use RDA over LDA or QDA?
#
#
# What is the time complexity of training LDA?
#
# What is the time complexity of training QDA?
#
# How does sample size affect LDA vs QDA performance?
#
# Why does QDA require more data than LDA?
#
# What is the bias-variance tradeoff in LDA vs QDA?
#
#
# How is the within-class scatter matrix calculated?
#
# How is the between-class scatter matrix calculated?
#
# What is the Fisher criterion that LDA optimizes?
#
# How are eigenvalues/eigenvectors used in LDA?
#
# What does the magnitude of eigenvalues indicate in LDA?
#
#
# "When would you choose LDA over logistic regression?"
#
# "Your data is not Gaussian. Can you still use LDA?"
#
# "How would you decide between LDA and QDA?"
#
# "Explain LDA to a non-technical person"
#
# "What happens if classes have very different variances?"
#
# "How does LDA perform with imbalanced classes?"
#
#
# Prove that maximizing Fisher's criterion leads to eigenvectors of S_w^{-1}S_b
#
# Show that LDA is Bayes optimal under Gaussian assumptions with equal covariance
#
# Derive the posterior probability formula in LDA
#
# Prove that QDA decision boundaries are quadratic surfaces
#
# Show the relationship between LDA and Mahalanobis distance
#
#
# Implement LDA from scratch without sklearn
#
# Implement QDA from scratch
#
# Write code to visualize LDA decision boundaries
#
# Implement LDA for dimensionality reduction
#
# Code to check LDA assumptions
#
#
# What happens when n < d (more features than samples)?
#
# How does LDA handle perfectly separable classes?
#
# What if covariance matrix is not invertible?
#
# How does LDA perform with outliers?
#
# What happens with collinear features?
#
#
# What is Diagonal LDA (Naïve Bayes with Gaussian)?
#
# What is Shrinkage LDA?
#
# What is Flexible Discriminant Analysis (FDA)?
#
# What is Mixture Discriminant Analysis (MDA)?
#
# What is Sparse LDA?
#
#
# What metrics are appropriate for evaluating LDA/QDA?
#
# How do you validate LDA assumptions?
#
# Can LDA provide probability estimates?
#
# How do you interpret LDA coefficients?
#
# What is the confusion matrix for LDA?
#
#
# In what domains is LDA commonly used?
#
# When is QDA preferred in practice?
#
# Give examples where LDA assumptions likely hold
#
# Give examples where LDA assumptions likely fail
#
# How is LDA used in face recognition?
#
#
# How do you test for equality of covariance matrices?
#
# How do you test for multivariate normality?
#
# What is Box's M test?
#
# How do you test for linear separability?
#
#
# How does LDA minimize classification error?
#
# What loss function does LDA optimize?
#
# How can you incorporate different misclassification costs?
#
# What is the reject option in LDA?
#
#
# How do you visualize LDA in high dimensions?
#
# What is the geometric interpretation of LDA?
#
# How are LDA directions related to class means?
#
# How to plot confidence ellipses for LDA?
#
#
# How does LDA handle more than 2 classes?
#
# What is the "one-vs-rest" approach in LDA?
#
# How many discriminant functions for K classes?
#
# How to interpret multiple discriminant functions?
#
#
# Can LDA be used for feature selection?
#
# How does LDA handle irrelevant features?
#
# What is stepwise LDA?
#
# How does LDA compare with ANOVA for feature selection?
#
#
# What is the computational complexity of LDA prediction?
#
# How does LDA scale with number of features?
#
# How does LDA scale with number of classes?
#
# What are memory requirements for LDA vs QDA?
#
#
# How does shrinkage help in LDA?
#
# What is Pseudoinverse LDA?
#
# How does regularization affect decision boundaries?
#
# When is regularization most beneficial?
#
#
# How does LDA handle missing values?
#
# What imputation methods work well with LDA?
#
# Can EM algorithm be used with LDA?
#
#
# How do you implement LDA in sklearn?
#
# What are key parameters in sklearn's LDA?
#
# How to get discriminant functions from sklearn LDA?
#
# How to plot decision boundaries with sklearn?
#
#
# What is the connection between LDA and canonical correlation analysis?
#
# How is LDA related to Hotelling's T-squared?
#
# What is the Wilks' lambda statistic in LDA?
#
# How does LDA relate to MANOVA?
#
#
# What is kernel LDA?
#
# How does LDA work with nonlinear kernels?
#
# What is deep LDA?
#
# How to use LDA with neural networks?
#
# What is incremental LDA for streaming data?
#
#
# "You have 100 samples, 50 features, 3 classes. LDA or QDA?"
#
# "Your LDA model has 98% training accuracy but 60% test. Why?"
#
# "How would you improve LDA performance on non-Gaussian data?"
#
# "When would LDA fail miserably?"
#
# "How to choose between LDA and random forest?"
#
# How to test multivariate normality assumption?
#
# How to test homogeneity of covariance matrices?
#
# What to do if assumptions are violated?
#
# Are LDA results interpretable if assumptions are violated?
#
#
# Are LDA probability estimates well-calibrated?
#
# How to calibrate LDA probabilities?
#
# When are LDA probabilities reliable?
#
#
# How to compute confidence intervals for LDA coefficients?
#
# How to estimate uncertainty in LDA predictions?
#
# What is the standard error of discriminant functions?
#
#
# Why use LDA when we have deep learning?
#
# When does LDA outperform neural networks?
#
# How does LDA compare with SVM?
#
# LDA vs XGBoost: When to choose which?
#
#
# How to handle numerical stability in LDA?
#
# What is the effect of feature scaling on LDA?
#
# How to implement LDA with online learning?
#
# How to update LDA with new data?
#
#
# Show that LDA finds directions that maximize class separation
#
# Prove that LDA is equivalent to linear regression with dummy targets
#
# Show connection between LDA and optimal scoring
#
#
# What is the "peaking phenomenon" in LDA?
#
# How many samples per feature needed for LDA?
#
# What happens when number of features >> number of samples?
#
#
# How robust is LDA to outliers?
#
# What is robust LDA?
#
# How does LDA handle skewed distributions?
#
#
# What are the key advantages of LDA that keep it relevant today?
#
# When would you definitely NOT use LDA?
#
# What's the most common mistake people make with LDA?
#
# How has LDA evolved in the era of big data?
