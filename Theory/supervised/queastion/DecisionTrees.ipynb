# %% [markdown]
# Basic Concepts
# What is a decision tree, and how does it work?
#
# Explain the structure: root node, internal nodes, leaf nodes, branches.
#
# What are the advantages and disadvantages of decision trees?
#
# How do decision trees handle both classification and regression tasks?
#
#
# For Classification:
#
# What is Gini impurity? Derive the formula.
#
# What is Entropy/Information Gain? Explain with formula.
#
# What is Information Gain Ratio (used in C4.5)?
#
# Compare Gini vs. Entropy - which is faster and why?
#
# For Regression:
#
# What is variance reduction or MSE reduction?
#
# How does a regression tree make predictions?
#
# What is Chi-square criterion (used in CHAID)?
#
#
# Explain the recursive binary splitting algorithm.
#
# What is greedy search in tree building?
#
# How do you decide when to stop splitting? (stopping criteria)
#
# What are pre-pruning and post-pruning?
#
#
# How do decision trees handle categorical variables?
#
# How do they handle numerical variables?
#
# Can decision trees handle missing values? If yes, how?
#
# How are multi-class classification problems handled?
#
#
# What is maximum depth and its effect?
#
# What are minimum samples split and minimum samples leaf?
#
# What is maximum features parameter?
#
# How does criterion parameter affect the tree?
#
#
# Why is pruning necessary in decision trees?
#
# Explain cost complexity pruning (also called weakest link pruning).
#
# How does minimum impurity decrease work?
#
# Compare pre-pruning vs. post-pruning effectiveness.
#
# How do you interpret a decision tree?
#
# What is feature importance in decision trees?
#
# How is feature importance calculated? (Gini importance, permutation importance)
#
# How to visualize a decision tree in Python/R?
#
#
# What is the CART algorithm? How is it different from ID3/C4.5?
#
# Explain oblique decision trees.
#
# What are conditional inference trees?
#
# How do multivariate decision trees work?
#
#
# What is the overfitting problem in decision trees?
#
# Why are decision trees high variance estimators?
#
# How are decision trees unstable (small data changes cause big tree changes)?
#
# Can decision trees capture linear relationships efficiently?
#
#
# How to implement a decision tree from scratch (basic version)?
#
# Using scikit-learn: DecisionTreeClassifier and DecisionTreeRegressor
#
# How to tune decision tree hyperparameters with grid search?
#
# Best practices for preprocessing data for decision trees.
#
#
# Decision trees vs. logistic regression for classification
#
# Decision trees vs. linear regression for regression
#
# Gini impurity vs. Information Gain
#
# Decision trees vs. rule-based systems
#
#
# What are decision stumps?
#
# How do decision trees relate to Random Forests?
#
# How are decision trees used in Gradient Boosting Machines (GBM)?
#
# What is extremely randomized trees (ExtraTrees)?
#
#
# Can a decision tree learn XOR function? Why or why not?
#
# What happens if you have a dataset where all features are identical?
#
# How would you handle imbalanced classes in decision trees?
#
# Why are decision trees called non-parametric models?
#
# What is the time complexity of building a decision tree?
#
# How do decision trees handle outliers?
#
# Can decision trees provide probability estimates? How?
#
# Prove that Gini impurity for a binary class is maximum when classes are balanced.
#
# Derive the formula for Information Gain from Entropy.
#
# Show that for a binary classification with probabilities p and (1-p):
#
# Gini = 2p(1-p)
#
# Entropy = -p log₂(p) - (1-p) log₂(1-p)
#
# What is the relationship between cross-entropy and entropy?
#
#
# Credit scoring and risk assessment
#
# Medical diagnosis
#
# Customer segmentation
#
# Fraud detection
#
# Quality control in manufacturing
