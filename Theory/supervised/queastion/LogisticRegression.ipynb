# %% [markdown]
# What is logistic regression, and when is it used instead of linear regression?
#
# Why can't we use linear regression for binary classification?
#
# What is the logistic (sigmoid) function? Write its equation and properties.
#
# Interpret the coefficients in logistic regression (odds ratio).
# How do you convert predicted probabilities into class labels (threshold selection)?
#
# What is the decision boundary in logistic regression?
#
# Interpret a coefficient β₁ = 0.5 in terms of odds ratio.
#
# How does multicollinearity affect logistic regression?
#
# What is the confusion matrix? Define precision, recall, specificity.
#
# Explain ROC curve and AUC. What does AUC = 0.8 mean?
#
# What is the F1-score, and when is it useful?
#
# Compare accuracy vs. log-loss for logistic regression evaluation.
# Multinomial logistic regression for >2 classes.
#
# Ordinal logistic regression for ordered categories.
#
# Regularized logistic regression (L1/L2 penalties).
#
# What is softmax regression, and how does it relate to logistic regression?
# Does logistic regression assume linearity? If so, in what sense?
#
# Check for linearity of log-odds (Box-Tidwell test).
#
# What is the Hosmer-Lemeshow test?
#
# How to detect influential points in logistic regression?
# How to handle imbalanced classes in logistic regression?
#
# What is separation (complete or quasi-complete), and how does it affect estimation?
#
# Can logistic regression handle non-linear relationships? (Yes, via polynomial terms/interactions)
#
# How to implement logistic regression with regularization in Python/R?
# Logistic regression vs. linear discriminant analysis (LDA)
#
# Logistic regression vs. decision trees
#
# Logistic regression vs. SVM with linear kernel
#
# When would you choose probit regression over logistic regression?
# Derive the Hessian matrix for logistic regression.
#
# Show that the log-likelihood for logistic regression is concave.
#
# Explain Newton-Raphson vs. gradient descent for logistic regression.
#
# Bayesian logistic regression vs. frequentist approach.
# Why is logistic regression considered a linear model?
#
# Can logistic regression coefficients be negative? What does that mean?
#
# What happens if we use MSE instead of log-loss for logistic regression?
#
# Why don't we use R² for logistic regression?
