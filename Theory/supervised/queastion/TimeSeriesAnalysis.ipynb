# %% [markdown]
# What is a time series? Give examples from different domains.
#
# Explain the main components of a time series: trend, seasonality, cyclical, irregular.
#
# What are the differences between trend and seasonality?
#
# Why is time series analysis different from cross-sectional data analysis?
# Define stationarity (strict vs. weak stationarity).
#
# Why is stationarity important in time series modeling?
#
# How do you test for stationarity? (ADF test, KPSS test, visual inspection)
#
# What transformations can make a time series stationary? (differencing, log transform, detrending)
# Explain additive vs. multiplicative decomposition.
#
# How does STL decomposition work?
#
# What is seasonal adjustment, and why is it useful?
#
# Compare classical decomposition vs. X-13-ARIMA-SEATS.
# Define ACF and PACF. How are they different?
#
# How do you interpret ACF and PACF plots?
#
# What is the Ljung-Box test, and what does it test?
#
# Explain autocorrelation function mathematically.
# What does ARIMA(p,d,q) stand for? Explain each component.
#
# How do you choose p, d, q parameters using ACF/PACF?
#
# What is seasonal ARIMA (SARIMA)?
#
# How do you interpret AR and MA coefficients?
#
# What is differencing, and how does it relate to integration order (d)?
# Compare AIC, BIC for ARIMA model selection.
#
# How do you perform model diagnostics on ARIMA residuals?
#
# What should residual ACF look like for a good ARIMA model?
#
# Explain the Box-Jenkins methodology.
# How does ARIMA forecasting work?
#
# What are forecast intervals, and how are they calculated?
#
# Compare one-step ahead vs. multi-step ahead forecasting.
#
# How do you evaluate forecast accuracy? (MAE, RMSE, MAPE, MASE)
# Exponential Smoothing (simple, double, triple/Holt-Winters)
#
# ARCH/GARCH models for volatility clustering
#
# Vector Autoregression (VAR) for multiple time series
#
# State Space Models and Kalman Filter
#
# Prophet model by Facebook - when to use it?
#
#
# How to handle missing values in time series?
#
# What is intervention analysis (structural breaks)?
#
# Explain cointegration and error correction models.
#
# What are leading, lagging, and coincident indicators?
#
# How can you use machine learning for time series? (feature engineering)
#
# What is sliding window approach for time series forecasting?
#
# Compare traditional statistical methods (ARIMA) vs. ML methods (LSTM, XGBoost) for time series.
#
# What is cross-validation for time series (time series split vs. k-fold)?
# How to decompose time series in Python/R?
#
# Step-by-step guide to fitting ARIMA in Python (statsmodels).
#
# How to detect seasonality programmatically?
#
# Best practices for preprocessing time series data.
#
#
# Why can't we use standard cross-validation for time series?
#
# What happens if you fit ARIMA to non-stationary data?
#
# How would you forecast a time series with both trend and multiple seasonal patterns?
#
# When would you choose exponential smoothing over ARIMA?
#
# What is the random walk model, and how does it relate to ARIMA?
#
# Sales forecasting for retail
#
# Stock price prediction
#
# Energy demand forecasting
#
# Website traffic prediction
#
# Anomaly detection in time series
